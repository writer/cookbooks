# %% [markdown]
# # Advanced Instructor patterns with Writer
#
# This cookbook shows you how to work with **complex nested Pydantic models** and implement **robust error handling** using Instructor with WRITER. After completing these steps, you can extract structured data using enums, regex validation, and conditional fields, apply automatic retry and repair patterns, and perform streaming extraction.
#
# Topics covered:
# - [Complex nested Pydantic models](https://python.useinstructor.com/getting-started/#working-with-complex-models) with enums, regex, and conditional fields
# - [Validation rules and automatic retry/repair patterns](https://python.useinstructor.com/getting-started/#validation-and-error-handling)
# - [Streaming extraction](https://python.useinstructor.com/getting-started/#streaming-responses) using async generator style
#
# ## Prerequisites
#
# Before you begin, ensure you have the following:
#
# - A [WRITER AI Studio](https://app.writer.com/register) account
# - An API key, which you can obtain by following the [API quickstart](https://dev.writer.com/home/quickstart)

# %% [markdown]
# ## Install dependencies
#
# Run this cell to install the required libraries:

# %%
# %pip install "instructor[writer]" writer-sdk pydantic

# %% [markdown]
# ## Environment setup
#
# Set the `WRITER_API_KEY` environment variable. You can store this value in a `.env` file in the root of the project, or enter it interactively when prompted:

# %%
import getpass
import os

import instructor
from writerai import Writer


if not os.getenv("WRITER_API_KEY"):
    os.environ["WRITER_API_KEY"] = getpass.getpass("Enter your WRITER API key: ")

# Initialize the Instructor client with WRITER
client = instructor.from_writer(Writer(api_key=os.getenv('WRITER_API_KEY')))

# %% [markdown]
# ## Define complex models
#
# The following code imports required libraries, defines Enum-based role types, and builds nested Pydantic models with validation:

# %%
from typing import List, Optional, Literal, Union, Iterable, Type
from pydantic import BaseModel, Field, field_validator
from enum import Enum
import re
import asyncio

class Role(str, Enum):
    employee = 'employee'
    contractor = 'contractor'
    intern = 'intern'

class Address(BaseModel):
    street: str
    city: str
    state: str
    postal_code: str = Field(..., description='ZIP or ZIP+4')
    country: Optional[str] = 'USA'

    @field_validator('postal_code')
    def zip_must_match(cls, v):
        if not re.match(r'^\d{5}(-\d{4})?$', v):
            raise ValueError('postal_code must be 5 digits or ZIP+4')
        return v

class Person(BaseModel):
    full_name: str
    age: int = Field(..., gt=0, lt=120)
    role: Role
    email: Optional[str] = None
    addresses: List[Address] = Field(default_factory=list)

    @field_validator('full_name')
    def must_have_first_and_last(cls, v):
        if len(v.split()) < 2:
            raise ValueError('full_name must include first and last name')
        return v

# %% [markdown]
# ### Extract object from unstructured text
#
# The following example demonstrates extraction from informal, unstructured input. Instructor parses the text, extracts relevant fields, and constructs a `Person` object. Pydantic automatically validates full name format, age range, role enum, email, and ZIP code format:

# %%
example_messages_person = [
    {"role": "user", "content": "John Smith, 35, employee, john.smith@acme.com, address: 123 Main St, Springfield, IL 62704"},
]

user = client.create(
    model="palmyra-x5",
    messages=example_messages_person,
    response_model=Person,
)
print(user)

# %% [markdown]
# ### Extract object from detailed narrative
#
# The following example demonstrates extraction from a longer narrative with additional context. Despite the input containing multiple sentences and extra details about work activities, Instructor parses the narrative, identifies the relevant fields, and constructs a `Person` object with proper validation:

# %%
example_messages_person = [
    {"role": "user", "content": (
"We were working with John Smith, a 35-year-old employee at our company. John has been involved in several key projects over the past year, contributing both to team planning and execution. He is known for his attention to detail, reliability, and collaborative approach."
"He can be reached via email at john.smith@acme.com,"
"and his office is located at 123 Main St, Springfield, IL 62704. In addition to his regular duties, John occasionally mentors new team members and participates in cross-department initiatives, which has helped improve workflow efficiency."
    )},
]

user = client.create(
    model="palmyra-x5",
    messages=example_messages_person,
    response_model=Person,
)

print(user)

# %% [markdown]
# ### Handle partial or ambiguous input with retries
#
# When `max_retries` is specified, Instructor automatically retries the request to attempt improved parsing. If the model still fails to generate a valid response, the exception handling captures both the last attempted message content and the underlying exception for debugging:

# %%
example_messages_person = [
    {"role": "user", "content": "John"},
]
try:
    user = client.create(
        model="palmyra-x5",
        messages=example_messages_person,
        response_model=Person,
        max_retries=2
    )
except Exception as e:
    print(f"content: {e.failed_attempts[0].completion.choices[0].message.content}")
    print(f"exception: {e.failed_attempts[0].exception}")

# %% [markdown]
# ## Stream extraction results
#
# The following example demonstrates **streaming extraction** using Instructor. This approach is useful for:
#
# - Monitoring structured extraction in real time
# - Handling long or complex inputs without waiting for the full response
# - Building pipelines that can act on partially extracted data immediately
#
# Each chunk represents a progressively completed `Person` object, with fields gradually populated as the model processes the input:

# %%
example_messages_person = [
    {"role": "user", "content": (
"We were working with John Smith, a 35-year-old employee at our company. John has been involved in several key projects over the past year, contributing both to team planning and execution. He is known for his attention to detail, reliability, and collaborative approach."
"He can be reached via email at john.smith@acme.com,"
"and his office is located at 123 Main St, Springfield, IL 62704. In addition to his regular duties, John occasionally mentors new team members and participates in cross-department initiatives, which has helped improve workflow efficiency."
    )},
]

stream = client.chat.completions.create_partial(
    model="palmyra-x5",
    messages=example_messages_person,
    response_model=Person,
)
for chunk in stream:
    print(chunk)
